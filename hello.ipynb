# %% [markdown]
# # Introduction to Jupyter Notebook
#
# To run this you need numpy
#
# ```bash
# pip install numpy
# ```
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/a-suwal/demo/blob/main/hello.ipynb)

# %%
print("Hello World")
# Out:
# Hello World

# %%
import os

# %%
os.getcwd()
# Out:
# 'd:\\Geographic_Software_Design\\demo'
